# %% [markdown]
# # Images and Layers

# %%
# %%bash
# docker images ls
# echo '----------HISTORY-nginx----------'
# docker history nginx:latest
# echo '----------HISTORY-mysql----------'
# docker image history mysql
# Out:
# REPOSITORY          TAG                 IMAGE ID            CREATED             SIZE
# ----------HISTORY-nginx----------
# IMAGE               CREATED             CREATED BY                                      SIZE                COMMENT
# 4bb46517cac3        2 months ago        /bin/sh -c #(nop)  CMD ["nginx" "-g" "daemon…   0B
# <missing>           2 months ago        /bin/sh -c #(nop)  STOPSIGNAL SIGTERM           0B
# <missing>           2 months ago        /bin/sh -c #(nop)  EXPOSE 80                    0B
# <missing>           2 months ago        /bin/sh -c #(nop)  ENTRYPOINT ["/docker-entr…   0B
# <missing>           2 months ago        /bin/sh -c #(nop) COPY file:0fd5fca330dcd6a7…   1.04kB
# <missing>           2 months ago        /bin/sh -c #(nop) COPY file:1d0a4127e78a26c1…   1.96kB
# <missing>           2 months ago        /bin/sh -c #(nop) COPY file:e7e183879c35719c…   1.2kB
# <missing>           2 months ago        /bin/sh -c set -x     && addgroup --system -…   63.4MB
# ...

# %%
# !echo '----------Inspect-mysql----------'
# !docker image inspect mysql
# Out:
# ----------Inspect-mysql----------
# [
#     {
#         "Id": "sha256:0d64f46acfd1af4ee6a162f80c6e07e843761bf14d412060023bf0e69e720fb4",
#         "RepoTags": [
#             "mysql:latest"
#         ],
#         "RepoDigests": [
#             "mysql@sha256:c358e72e100ab493a0304bda35e6f239db2ec8c9bb836d8a427ac34307d074ed"
#         ],
#         "Parent": "",
#         "Comment": "",
#         "Created": "2020-08-04T23:20:04.627419886Z",
#         "Container": "db7bc9b1228659d42e15e8dbc621e324af304ac34f9fb6e3372800973e5ae94c",
#         "ContainerConfig": {
#             "Hostname": "db7bc9b12286",
#             "Domainname": "",
#             "User": "",
#             "AttachStdin": false,
#             "AttachStdout": false,
#             "AttachStderr": false,
#             "ExposedPorts": {
#                 "3306/tcp": {},
#                 "33060/tcp": {}
#             },
#             "Tty": false,
#             "OpenStdin": false,
#             "StdinOnce": false,
# ...
